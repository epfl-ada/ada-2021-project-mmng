# %%
import prepro_pipeline.py
# Out:
# ...
#  Starting data preprocessing
# ------------------------------------------------------------------
#  Loading and preparing wikidata dump (10s-60s)
# DONE
#
# ...
#  Starting file preprocessing
#  	Writing outputs to: data.nosync/processed/fulldataset_fullypreprocessed.json.bz2
# ------------------------------------------------------------------
# Processing file: data.nosync/quotebank/quotes-2015.json.bz2
# ...
