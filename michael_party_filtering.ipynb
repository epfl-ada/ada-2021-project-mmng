# %%
# %load_ext autoreload
# %autoreload 2

import bz2
import json

import pickle

# import numpy
import pandas as pd

from helpers import *

# %%
# Read file in chunks
with pd.read_json(QUOTES_2020_PATH, lines=True, compression='bz2', chunksize=10000) as df_reader:
    for chunk in df_reader:
        break


df_quotes = chunk

# %%
# Read parquet Wikidata file
df_sa = pd.read_parquet(SPEAKER_ATTRIBUTES_PATH)

# %%
print(df_quotes.shape)
df_quotes.head()
# Out:
# (10000, 9)
#              quoteID                                          quotation  \
# 0  2020-01-28-000082  [ D ] espite the efforts of the partners to cr...
# 1  2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 2  2020-02-10-000142  ... He (Madhav) also disclosed that the illega...
# 3  2020-02-15-000053                  ... [ I ] f it gets to the floor,
# 4  2020-01-24-000168  [ I met them ] when they just turned 4 and 7. ...
#
#                speaker         qids                date  numOccurrences  \
# 0                 None           [] 2020-01-28 08:04:05               1
# 1           Sue Myrick    [Q367796] 2020-01-16 12:00:13               1
# 2                 None           [] 2020-02-10 23:45:54               1
# 3                 None           [] 2020-02-15 14:12:51               2
# 4  Meghan King Edmonds  [Q20684375] 2020-01-24 20:37:09               4
#
#                                               probas  \
# 0  [[None, 0.7272], [Prime Minister Netanyahu, 0....
# 1  [[Sue Myrick, 0.8867], [None, 0.0992], [Ron Wy...
# 2            [[None, 0.8926], [Prakash Rai, 0.1074]]
# 3             [[None, 0.581], [Andy Harris, 0.4191]]
# 4  [[Meghan King Edmonds, 0.5446], [None, 0.2705]...
#
#                                                 urls phase
# 0  [http://israelnationalnews.com/News/News.aspx/...     E
# 1  [http://thehill.com/opinion/international/4782...     E
# 2  [https://indianexpress.com/article/business/ec...     E
# 3  [https://patriotpost.us/opinion/68622-trump-bu...     E
# 4  [https://people.com/parents/meghan-king-edmond...     E

# %%
def quotes_clean(df_quotes):
    df_quotes = df_quotes.drop('phase', axis=1).drop('urls', axis=1).drop('probas', axis=1)

    # Drop tables which don't have any qid
    df_has_qids = df_quotes[df_quotes['qids'].map(lambda x: len(x)) > 0].copy()

    # Pick 1st qid in qid list
    df_has_qids['top_qid'] = df_has_qids['qids'].map(lambda x: x[0])

    df_has_qids.drop('qids', axis=1, inplace=True)

    return df_has_qids

df_quotes_clean = quotes_clean(df_quotes)

# %%
df_quotes_clean
# Out:
#                 quoteID                                          quotation  \
# 1     2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 4     2020-01-24-000168  [ I met them ] when they just turned 4 and 7. ...
# 7     2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 8     2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 9     2020-03-19-000276  [ These ] actions will allow households who ha...
# ...                 ...                                                ...
# 9990  2020-02-17-085956                  whoever is the interested player,
# 9995  2020-03-02-078576                         Why now, 2021? Here's why,
# 9996  2020-04-14-074488  Why should a running back be treated less than...
# 9997  2020-04-15-078413  Why would I leave here where I'm healthy, to t...
# 9999  2020-03-26-086246  will not be the first commissioner of an Ameri...
#
#                   speaker                date  numOccurrences    top_qid
# 1              Sue Myrick 2020-01-16 12:00:13               1    Q367796
# 4     Meghan King Edmonds 2020-01-24 20:37:09               4  Q20684375
# 7            Dexter Smith 2020-01-17 13:03:00               1   Q5268447
# 8         Barry Coppinger 2020-04-02 14:18:20               1   Q4864119
# 9              Ben Carson 2020-03-19 19:14:00               1    Q816459
# ...                   ...                 ...             ...        ...
# 9990   Hardeep Singh Puri 2020-02-17 10:15:26               6   Q5655835
# 9995    Michael J. Graham 2020-03-02 21:03:20               1   Q6831418
# 9996          Mark Ingram 2020-04-14 22:03:37               1    Q452154
# 9997       Pauline Pearce 2020-04-15 10:10:33               1  Q55076551
# 9999          Adam Silver 2020-03-26 22:20:01               1   Q4679786
#
# [6575 rows x 6 columns]

# %%
REPUBLICAN_QID = 'Q29468'
DEMOCRAT_QID = 'Q29552'

# def filter_party(df_sa, party_qid):
#     df_has_party = df_sa[df_sa['party'].notna()]
#     return df_has_party[df_has_party['party'].map(lambda x: party_qid in x)]


def sa_keep_congress_members(df_sa):
    return df_sa[df_sa['US_congress_bio_ID'].notna()]


def sa_label_parties(df_sa):

    def label_party(parties):
        # TODO Figure out what to do if a person in a member of multiple parties at the same time
        if REPUBLICAN_QID in parties and DEMOCRAT_QID in parties:
            return None
        elif REPUBLICAN_QID in parties:
            return 'R'
        elif DEMOCRAT_QID in parties:
            return 'D'
        else:
            return None

    df_has_party = df_sa[df_sa['party'].notna()].copy()

    # Use function label_party to assign single letter party code to each row
    df_has_party['party_label'] = df_has_party['party'].map(label_party)

    # Drop any person that didn't get attributed a party_label
    df_has_party.dropna(subset=['party_label'], inplace=True)

    return df_has_party
    

def sa_keep_useful_stuff(df_sa):
    return df_sa[['label', 'id', 'party_label']]

# republicans = filter_party(df_sa, REPUBLICAN_QID)
# democrats = filter_party(df_sa, DEMOCRAT_QID)

# %%
df_sa_party_labeled = sa_label_parties(df_sa)

print(df_sa_party_labeled.shape)
df_sa_party_labeled.head()
# Out:
# (49997, 16)
#                                               aliases  \
# 3   [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 14  [Mary Louise Streep, Meryl Louise Streep, Stre...
# 57          [Elisha Meredith, Elisha Edward Meredith]
# 71  [Thomas Matthew DeLonge, Thomas DeLonge, Ava D...
# 79              [Willard Mitt Romney, Pierre Delecto]
#
#               date_of_birth nationality      gender   lastrevid ethnic_group  \
# 3   [+1946-07-06T00:00:00Z]       [Q30]  [Q6581097]  1395142029         None
# 14  [+1949-06-22T00:00:00Z]       [Q30]  [Q6581072]  1388232380         None
# 57  [+1848-12-26T00:00:00Z]       [Q30]  [Q6581097]  1395914283         None
# 71  [+1975-12-13T00:00:00Z]       [Q30]  [Q6581097]  1377404832         None
# 79  [+1947-03-12T00:00:00Z]       [Q30]  [Q6581097]  1393565531         None
#
#    US_congress_bio_ID                                         occupation  \
# 3                None  [Q82955, Q15982858, Q18814623, Q1028181, Q1408...
# 14               None  [Q10800557, Q2259451, Q10798782, Q2405480, Q33...
# 57            M000647                                   [Q82955, Q40348]
# 71               None    [Q855091, Q177220, Q753110, Q488205, Q18921227]
# 79            R000615    [Q82955, Q15978655, Q43845, Q15980158, Q219477]
#
#        party                academic_degree     id               label  \
# 3   [Q29468]                           None   Q207      George W. Bush
# 14  [Q29552]                           None   Q873        Meryl Streep
# 57  [Q29552]                           None  Q3251  Elisha E. Meredith
# 71  [Q29552]                           None  Q4270         Tom DeLonge
# 79  [Q29468]  [Q1765120, Q191701, Q1540185]  Q4496         Mitt Romney
#
#                                  candidacy  type                    religion  \
# 3   [Q327959, Q464075, Q3586276, Q4450587]  item  [Q329646, Q682443, Q33203]
# 14                                    None  item                     [Q7066]
# 57                                    None  item                        None
# 71                                    None  item                        None
# 79   [Q937607, Q4226, Q4791860, Q17100322]  item                    [Q42504]
#
#    party_label
# 3            R
# 14           D
# 57           D
# 71           D
# 79           R

# %%
df_sa_party_labeled_congressmen = sa_keep_useful_stuff(sa_keep_congress_members(df_sa_party_labeled))

print(df_sa_party_labeled_congressmen.shape)
df_sa_party_labeled_congressmen.head()
# Out:
# (10261, 3)
#                   label      id party_label
# 57   Elisha E. Meredith   Q3251           D
# 79          Mitt Romney   Q4496           R
# 196       Richard Nixon   Q9588           R
# 235          John Tyler  Q11881           D
# 236       James K. Polk  Q11891           D

# %%
df_sa_party_labeled = sa_keep_useful_stuff(df_sa_party_labeled)

# %%
df_quotes_clean.shape
# Out:
# (6575, 6)

# %%
df_merged = df_quotes_clean.merge(df_sa_party_labeled_congressmen, left_on='top_qid', right_on='id').drop(['top_qid', 'label'], axis=1)
df_merged
# Out:
#                quoteID                                          quotation  \
# 0    2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 1    2020-01-26-000499  a few of the candidates who will do better in ...
# 2    2020-01-26-040663  The generational thing is important, quite hon...
# 3    2020-01-20-000982                        a host of other protections
# 4    2020-03-24-004650  And they are working towards delivering their ...
# ..                 ...                                                ...
# 332  2020-03-31-054725  The stimulus has failed. But anyone with commo...
# 333  2020-02-23-033117  There are issues to resolve in the civil servi...
# 334  2020-04-16-056321  Under my plan, we will put Americans back to w...
# 335  2020-01-27-090364  We have to have somebody that wants to come in...
# 336  2020-02-15-054670  We must do more to examine the sources of this...
#
#            speaker                date  numOccurrences         id party_label
# 0       Sue Myrick 2020-01-16 12:00:13               1    Q367796           R
# 1    Dave Loebsack 2020-01-26 13:21:36              11    Q771586           D
# 2    Dave Loebsack 2020-01-26 13:21:36              11    Q771586           D
# 3     Debbie Lesko 2020-01-20 15:32:48               1  Q16731415           R
# 4      Mike Pompeo 2020-03-24 03:45:00               2    Q473239           R
# ..             ...                 ...             ...        ...         ...
# 332   Cory Gardner 2020-03-31 14:14:09               1   Q1135774           R
# 333    David Davis 2020-02-23 12:01:00               1   Q1174175           R
# 334  Jeff Sessions 2020-04-16 16:04:20               1    Q358443           R
# 335     Cindy Axne 2020-01-27 00:00:00              31  Q58324150           D
# 336     Joni Ernst 2020-02-15 22:00:35               1  Q13475242           R
#
# [337 rows x 7 columns]
