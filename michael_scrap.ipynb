# %%
# %load_ext autoreload
# %autoreload 2

import bz2
import json

import pickle

import pandas as pd

from helpers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Read file in chunks

def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

c = 0

with pd.read_json(QUOTES_2020_PATH, lines=True, compression='bz2', chunksize=10000) as df_reader:
    for chunk in df_reader:
        c=chunk
        process_chunk(chunk)
        break

chunk.head()

df_quotes = chunk
# Out:
# Processing chunk with 10000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')

# %%
import bz2
import json

path_to_file = '/content/drive/MyDrive/Quotebank/quotes-2020.json.bz2' 
path_to_out = '/content/quotes-2020-domains.json.bz2'

with bz2.open(path_to_file, 'rb') as s_file:
    with bz2.open(path_to_out, 'wb') as d_file:
        for instance in s_file:
            instance = json.loads(instance) # loading a sample
            urls = instance['urls'] # extracting list of links
            domains = []
            for url in urls:
                tld = get_domain(url)
                domains.append(tld)
            instance['domains'] = domains # updating the sample with domain name
            d_file.write((json.dumps(instance)+'\n').encode('utf-8')) # writing in the new file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-7b753c3b4622> in <module>
#       5 path_to_out = '/content/quotes-2020-domains.json.bz2'
#       6
# ----> 7 with bz2.open(path_to_file, 'rb') as s_file:
#       8     with bz2.open(path_to_out, 'wb') as d_file:
#       9         for instance in s_file:
#
# ~/anaconda3/lib/python3.8/bz2.py in open(filename, mode, compresslevel, encoding, errors, newline)
#     320
#     321     bz_mode = mode.replace("t", "")
# --> 322     binary_file = BZ2File(filename, bz_mode, compresslevel=compresslevel)
#     323
#     324     if "t" in mode:
#
# ~/anaconda3/lib/python3.8/bz2.py in __init__(self, filename, mode, buffering, compresslevel)
#      94
#      95         if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 96             self._fp = _builtin_open(filename, mode)
#      97             self._closefp = True
#      98             self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Quotebank/quotes-2020.json.bz2'

# %%
# Read file line by line

eee=0
with bz2.open(QUOTES_2020_PATH, 'rb') as s_file:
    for line in s_file:
        line=json.loads(line)
        eee=line
        break

eee
# Out:
# {'quoteID': '2020-01-28-000082',
#  'quotation': '[ D ] espite the efforts of the partners to create a non-political award that unites the Jewish people, some have incorrectly interpreted the participation of the Office of the Prime Minister in the Genesis Prize as bringing a political dimension to this important initiative,',
#  'speaker': 'None',
#  'qids': [],
#  'date': '2020-01-28 08:04:05',
#  'numOccurrences': 1,
#  'probas': [['None', '0.7272'],
#   ['Prime Minister Netanyahu', '0.2445'],
#   ['Natan Sharansky', '0.0283']],
#  'urls': ['http://israelnationalnews.com/News/News.aspx/275210'],
#  'phase': 'E'}

# %%
# Write json to pickle (with or without compression)

eee=0

i = 0

with bz2.open(QUOTES_2020_PATH, 'rb') as s_file:
    with bz2.open(DATA_FOLDER + 'quotesquotes-2020.pkl', 'wb') as d_file:
        for line in s_file:
            line=json.loads(line)
            pickle.dump(line, d_file)

            i+= 1
            if i > 100000:
                break

            # eee=line
            # break

# eee

# %%
# with open(DATA_FOLDER + 'quotesquotes-2020_small.pkl') as s_file:

with pd.read_json(QUOTES_2020_PATH, lines=True, compression='bz2', chunksize=100) as df_reader:

# %% [markdown]
# ### Read Parquet Wikidata

# %%
df_sa = pd.read_parquet(SPEAKER_ATTRIBUTES_PATH)

# %%
# df_quotes.where(len(df_quotes['qids']) == 1)
# print(df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 0].shape)
# print(df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 1].shape)
# print(df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 2].shape)
# print(df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 3].shape)
# print(df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 4].shape)
# print(df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 5].shape)

# df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 5]

df_quotes[df_quotes['qids'].map(lambda x: len(x)) == 1]
# Out:
#                 quoteID                                          quotation  \
# 1     2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 4     2020-01-24-000168  [ I met them ] when they just turned 4 and 7. ...
# 7     2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 8     2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 9     2020-03-19-000276  [ These ] actions will allow households who ha...
# ...                 ...                                                ...
# 9990  2020-02-17-085956                  whoever is the interested player,
# 9995  2020-03-02-078576                         Why now, 2021? Here's why,
# 9996  2020-04-14-074488  Why should a running back be treated less than...
# 9997  2020-04-15-078413  Why would I leave here where I'm healthy, to t...
# 9999  2020-03-26-086246  will not be the first commissioner of an Ameri...
#
#                   speaker         qids                date  numOccurrences  \
# 1              Sue Myrick    [Q367796] 2020-01-16 12:00:13               1
# 4     Meghan King Edmonds  [Q20684375] 2020-01-24 20:37:09               4
# 7            Dexter Smith   [Q5268447] 2020-01-17 13:03:00               1
# 8         Barry Coppinger   [Q4864119] 2020-04-02 14:18:20               1
# 9              Ben Carson    [Q816459] 2020-03-19 19:14:00               1
# ...                   ...          ...                 ...             ...
# 9990   Hardeep Singh Puri   [Q5655835] 2020-02-17 10:15:26               6
# 9995    Michael J. Graham   [Q6831418] 2020-03-02 21:03:20               1
# 9996          Mark Ingram    [Q452154] 2020-04-14 22:03:37               1
# 9997       Pauline Pearce  [Q55076551] 2020-04-15 10:10:33               1
# 9999          Adam Silver   [Q4679786] 2020-03-26 22:20:01               1
#
#                                                  probas  \
# 1     [[Sue Myrick, 0.8867], [None, 0.0992], [Ron Wy...
# 4     [[Meghan King Edmonds, 0.5446], [None, 0.2705]...
# 7                [[Dexter Smith, 0.924], [None, 0.076]]
# 8           [[Barry Coppinger, 0.9017], [None, 0.0983]]
# 9                [[Ben Carson, 0.9227], [None, 0.0773]]
# ...                                                 ...
# 9990     [[Hardeep Singh Puri, 0.9405], [None, 0.0595]]
# 9995      [[Michael J. Graham, 0.6261], [None, 0.3739]]
# 9996  [[Mark Ingram, 0.5275], [None, 0.4657], [Chris...
# 9997         [[Pauline Pearce, 0.8222], [None, 0.1778]]
# 9999  [[Adam Silver, 0.5877], [None, 0.3937], [Jay M...
#
#                                                    urls phase
# 1     [http://thehill.com/opinion/international/4782...     E
# 4     [https://people.com/parents/meghan-king-edmond...     E
# 7     [http://www.sloughexpress.co.uk/gallery/slough...     E
# 8     [http://www.theweek.co.uk/106479/why-police-ar...     E
# 9     [https://mortgageorb.com/hud-fha-suspend-forec...     E
# ...                                                 ...   ...
# 9990  [https://www.livemint.com/news/india/-air-indi...     E
# 9995  [https://thecourier.com/ohio-news/2020/03/02/p...     E
# 9996  [http://registercitizen.com/sports/article/Ing...     E
# 9997  [https://www.bbc.co.uk/news/uk-england-london-...     E
# 9999  [http://sportsbusinessdaily.com/Daily/Issues/2...     E
#
# [4832 rows x 9 columns]

# %%
df_sa
# Out:
#                                                    aliases  \
# 0        [Washington, President Washington, G. Washingt...
# 1        [Douglas Noel Adams, Douglas Noël Adams, Dougl...
# 2            [Paul Marie Ghislain Otlet, Paul Marie Otlet]
# 3        [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 4        [Velázquez, Diego Rodríguez de Silva y Velázqu...
# ...                                                    ...
# 9055976                                    [Barker Howard]
# 9055977                                 [Charles Macomber]
# 9055978                                               None
# 9055979                                               None
# 9055980                                       [Fred Trull]
#
#                    date_of_birth     nationality      gender   lastrevid  \
# 0        [+1732-02-22T00:00:00Z]  [Q161885, Q30]  [Q6581097]  1395141751
# 1        [+1952-03-11T00:00:00Z]          [Q145]  [Q6581097]  1395737157
# 2        [+1868-08-23T00:00:00Z]           [Q31]  [Q6581097]  1380367296
# 3        [+1946-07-06T00:00:00Z]           [Q30]  [Q6581097]  1395142029
# 4        [+1599-06-06T00:00:00Z]           [Q29]  [Q6581097]  1391704596
# ...                          ...             ...         ...         ...
# 9055976                     None           [Q30]  [Q6581097]  1397399351
# 9055977                     None           [Q30]  [Q6581097]  1397399471
# 9055978  [+1848-04-01T00:00:00Z]            None  [Q6581072]  1397399751
# 9055979  [+1899-03-18T00:00:00Z]            None  [Q6581072]  1397399799
# 9055980                     None           [Q30]  [Q6581097]  1397400809
#
#         ethnic_group US_congress_bio_ID  \
# 0               None            W000178
# 1         [Q7994501]               None
# 2               None               None
# 3               None               None
# 4               None               None
# ...              ...                ...
# 9055976         None               None
# 9055977         None               None
# 9055978         None               None
# 9055979         None               None
# 9055980         None               None
#
#                                                 occupation      party  \
# 0        [Q82955, Q189290, Q131512, Q1734662, Q294126, ...  [Q327591]
# 1        [Q214917, Q28389, Q6625963, Q4853732, Q1884422...       None
# 2        [Q36180, Q40348, Q182436, Q1265807, Q205375, Q...       None
# 3        [Q82955, Q15982858, Q18814623, Q1028181, Q1408...   [Q29468]
# 4                                               [Q1028181]       None
# ...                                                    ...        ...
# 9055976                                           [Q82955]       None
# 9055977                                           [Q82955]       None
# 9055978                                               None       None
# 9055979                                               None       None
# 9055980                                           [Q82955]       None
#
#         academic_degree          id                label  \
# 0                  None         Q23    George Washington
# 1                  None         Q42        Douglas Adams
# 2                  None       Q1868           Paul Otlet
# 3                  None        Q207       George W. Bush
# 4                  None        Q297      Diego Velázquez
# ...                 ...         ...                  ...
# 9055976            None  Q106406560     Barker B. Howard
# 9055977            None  Q106406571  Charles H. Macomber
# 9055978            None  Q106406588           Dina David
# 9055979            None  Q106406593        Irma Dexinger
# 9055980            None  Q106406643        Fred F. Trull
#
#                                       candidacy  type  \
# 0                            [Q698073, Q697949]  item
# 1                                          None  item
# 2                                          None  item
# 3        [Q327959, Q464075, Q3586276, Q4450587]  item
# 4                                          None  item
# ...                                         ...   ...
# 9055976                                    None  item
# 9055977                                    None  item
# 9055978                                    None  item
# 9055979                                    None  item
# 9055980                                    None  item
#
#                            religion
# 0                         [Q682443]
# 1                              None
# 2                              None
# 3        [Q329646, Q682443, Q33203]
# 4                              None
# ...                             ...
# 9055976                        None
# 9055977                        None
# 9055978                        None
# 9055979                        None
# 9055980                        None
#
# [9055981 rows x 15 columns]

# %%
df_quotes.join(df_sa, on='')
