# %%
# if you dont have chartmodels pip install it (uncomment next line of code)
#!pip install chart_studio
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
import numpy as np
import pandas as pd
from helpers import *
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import chart_studio
import plotly.express as px
import chart_studio.plotly as py
import chart_studio.tools as tls

# %%
def send_figure_to_internet(fig,filename):
    """uploads a figure to pyplot express api service in order to include them in our website"""
    username = 'ogim'
    api_key = 'z9ZRECEZuhRpmGQjGcMX' # your api key - go to profile > settings > regenerate key
    chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
    url = py.plot(fig, filename = filename, auto_open=True)
    print(url)
    print('link:')
    print(tls.get_embed(url)) #change to your url

# %%
# data import
file = QUOTES_LABELED_CLEANED_PREDICTED
data = pd.read_json(file, lines=True, compression='bz2')
display(data.head(5))
# Out:
#                    quoteID                                          quotation  \
# 0        2015-08-31-000271  ... a great day for veterans here in Littleton...
# 1        2015-02-03-074650  The safety and security of our nation is at ri...
# 2        2015-05-10-027625  It's been my experience that the faith communi...
# 3        2015-09-01-113454  we need to bring the parents in so they can se...
# 4        2015-10-25-000242  ' It is not now, nor has it ever been, the gol...
# ...                    ...                                                ...
# 7090867  2020-02-10-100845  We're just worried about making sure we keep t...
# 7090868  2020-03-16-079753  We've all embraced strict proper hygiene proce...
# 7090869  2020-01-13-091997   What's important is that we keep moving forward.
# 7090870  2020-02-20-093793  When they want a bill, they bring the bill to ...
# 7090871  2020-02-09-057933  Who will respect different types of people, di...
#
#                   speaker                date         id party_label  \
# 0          Jeanne Shaheen 2015-08-31 02:10:00    Q270316           D
# 1          Jeanne Shaheen 2015-02-03 20:02:24    Q270316           D
# 2          Jeanne Shaheen 2015-05-10 22:48:46    Q270316           D
# 3          Jeanne Shaheen 2015-09-01 02:12:00    Q270316           D
# 4          Bernie Sanders 2015-10-25 14:12:35    Q359442           D
# ...                   ...                 ...        ...         ...
# 7090867  Sherrie Sprenger 2020-02-10 00:00:00   Q7495360           R
# 7090868     Robert Abrams 2020-03-16 12:00:00   Q2156314           D
# 7090869    Laurie Jinkins 2020-01-13 19:51:15   Q6501617           D
# 7090870       J.T. Wilcox 2020-02-20 22:12:45   Q6104393           R
# 7090871        Susan Wild 2020-02-09 15:08:23  Q58323072           D
#
#                                            quotation_clean data_use  prob_dem
# 0        great day veteran littleton across north count...    train  0.167571
# 1        safety security nation risk hold funding homel...     test  0.250535
# 2        experience faith community willing partner gov...    train  0.791943
# 3        need bring parent see manufacturing worked sho...    train  0.901145
# 4        ever gold standard trade agreement sander said...     test  0.980576
# ...                                                    ...      ...       ...
# 7090867  worried making sure keep balance expression ri...    train  0.284423
# 7090868  embraced strict proper hygiene procedure heard...    train  0.466911
# 7090869                      important keep moving forward    train  0.605841
# 7090870                         want bill bring bill floor    train  0.191033
# 7090871  respect different type people different opinio...    train  0.788821
#
# [7090872 rows x 9 columns]

# %%
#Loading of the pretrained model 
with open(MODEL_FINAL, 'rb') as file:
    clf_loaded = pickle.load(file)
#Loading of the pretrained vectorizer
with open(VECTORIZER_FINAL, 'rb') as file:
    vectorizer_loaded = pickle.load(file)
    
#Predicting function
def predict(quotes):
    y_proba = clf_loaded.predict_proba(vectorizer_loaded.transform(quotes))
    return y_proba[:,1]

# %% [markdown]
# ## How does a person's politicial opinions fluctuate over time?
# We have assigned a score to each quotation, now we can see how the political opinion of a politician or a group of politicians varies over time.
# #### Who is the influential Republican who has a score that is more polarized in the period (2015-2020)?
# To find out, we can fit a linear regression to the quotes scores and look at the slope of the time series.

# %%
#Just list of influential American politicians with theris Qids (from wikidata)
influential_R = ['Donald Trump','Arnold Schwarzenegger','Mike Pence','Ted Cruz','Sarah Palin','Mitch McConnel','Mitt Romney','Dick Cheney','Jeb Bush','Chris Christie','Rand Paul','Ben Carson','Henry Kissinger','Marco Rubio'] #source https://today.yougov.com/ratings/politics/fame/Republicans/all
id_inf_R = ['Q22686','Q2685','Q24313','Q2036942','Q43144','Q355522','Q4496','Q48259','Q221997','Q63879','Q463557','Q816459','Q66107','Q324546']
influential_D = ['Hilary Clinton','Barack Obama','Bernie Sanders','Bill Clinton','Joe Biden','Kamala Harris','Nancy Pelosi','Al Gore','Andrew Cuomo','Michael Bloomberg','Alexandria Ocasio-Cortez','Charles Schumer']
id_inf_D = ['Q6294','Q76','Q359442','Q1124','Q6279','Q10853588','Q170581','Q19673','Q11673','Q607','Q55223040','Q380900']

# %%
def get_quotes_by_speaker_id(ids,path,min_length_quote = 0,keep_RD = False , keep_exclusives = True):
    """given a set of speaker ids, extract all quotes of these speakers from dataset"""
    DF_PATH = path
    result = []
    i = 0
    with pd.read_json(DF_PATH,lines = True, compression= 'bz2',chunksize= 1000000) as df_reader:
        for df in df_reader:
            if not keep_RD:
                df = df[df.party_label != 'RD']
            if not keep_exclusives:
                df = df[df.party_label == 'RD']
            if min_length_quote >0:
                df = df[df.quotation_clean.apply(lambda x: len(x.split())) >= min_length_quote]
            df = df[df.id.isin(ids)]
            if df.shape[0] > 0:
                result.append(df)
            print(i, end='  ')
            i+=1
    return pd.concat(result)

# %%
# Create a dataframe with the information of influential politicians usefull for plotting
ls = (id_inf_R+id_inf_D)
#input file path
path = QUOTES_LABELED_CLEANED_PREDICTED
#retrieve data
df = get_quotes_by_speaker_id(ls,path,0,True,True)
# Out:
# 0  1  2  3  4  5  6  7

# %%
names = influential_D+influential_R
ids = id_inf_D+id_inf_R
dictionary = dict(zip(ids,names))
df['speaker'] = df['id'].apply(lambda x: dictionary[x])
parties = ['D' for i in range(len(id_inf_D))] + ['R' for i in range(len(influential_R))]

dictionary = dict(zip(ids,parties))
display(df)
# list with one df per politician
politiciansdfs = [df[df['speaker']== name] for name in names]
#list for storing resampled dfs of politicians
resampleddfs = []

#for each politician resample df and put it in listdf2
for dataf in politiciansdfs:
    #Save infos before resampling
    pid = dataf['id'].iloc[0]
    speaker = names[ids.index(pid)]
    #resample
    dataf = dataf[['date','prob_dem']].set_index('date').resample('3M').mean().reset_index()
    #Resetting infos after resampling
    dataf['speaker'] = speaker
    dataf['id'] = pid
    dataf['party'] = dataf['id'].apply(lambda x: dictionary[x])
    #append resampled df to list that will be used fot plotting
    resampleddfs.append(dataf)
df = pd.concat(resampleddfs)
# Out:
# {'Q6294': 'D', 'Q76': 'D', 'Q359442': 'D', 'Q1124': 'D', 'Q6279': 'D', 'Q10853588': 'D', 'Q170581': 'D', 'Q19673': 'D', 'Q11673': 'D', 'Q607': 'D', 'Q55223040': 'D', 'Q380900': 'D', 'Q22686': 'R', 'Q2685': 'R', 'Q24313': 'R', 'Q2036942': 'R', 'Q43144': 'R', 'Q355522': 'R', 'Q4496': 'R', 'Q48259': 'R', 'Q221997': 'R', 'Q63879': 'R', 'Q463557': 'R', 'Q816459': 'R', 'Q66107': 'R', 'Q324546': 'R'}
#                    quoteID                                          quotation  \
# 4        2015-10-25-000242  ' It is not now, nor has it ever been, the gol...
# 5        2015-10-15-015673  But if you talk about why the middle class is ...
# 6        2015-04-15-038299            If they destroy you, who is there left?
# 7        2015-07-30-060129         It would make everybody in America poorer.
# 8        2015-10-14-073757                 labor is the source of all wealth,
# ...                    ...                                                ...
# 7089847  2020-01-31-016764  Did you see it as a request for a political fa...
# 7089848  2020-01-07-066219  The Iranians will not be able to approach us o...
# 7090699  2020-03-05-051586  our past has set a framework which we must tra...
# 7090735  2020-03-05-014789                     everybody to be taken care of,
# 7090756  2020-01-02-048891  that we not allow our mission to be determined...
#
#                  speaker                date       id party_label  \
# 4         Bernie Sanders 2015-10-25 14:12:35  Q359442           D
# 5         Bernie Sanders 2015-10-15 10:07:01  Q359442           D
# 6         Bernie Sanders 2015-04-15 17:49:00  Q359442           D
# 7         Bernie Sanders 2015-07-30 01:49:15  Q359442           D
# 8         Bernie Sanders 2015-10-14 20:09:23  Q359442           D
# ...                  ...                 ...      ...         ...
# 7089847        Rand Paul 2020-01-31 19:48:31  Q463557           R
# 7089848        Rand Paul 2020-01-07 13:00:55  Q463557           R
# 7090699  Henry Kissinger 2020-03-05 10:10:36   Q66107           R
# 7090735       Ben Carson 2020-03-05 23:06:34  Q816459           R
# 7090756      Dick Cheney 2020-01-02 11:00:00   Q48259           R
#
#                                            quotation_clean data_use  prob_dem
# 4        ever gold standard trade agreement sander said...     test  0.972383
# 5        talk middle class disappearing almost income w...    train  0.999552
# 6                                             destroy left     none  0.471059
# 7                      would make everybody america poorer    train  0.993584
# 8                                      labor source wealth     none  0.270337
# ...                                                    ...      ...       ...
# 7089847  see request political favor coming election so...    train  0.042876
# 7089848  iranian able approach u diplomacy revenge adeq...     test  0.017127
# 7090699  past set framework must transcend fate past in...    train  0.068452
# 7090735                               everybody taken care     none  0.257053
# 7090756  allow mission determined others obligation wha...    train  0.058543
#
# [1654883 rows x 9 columns]
#          date  prob_dem         speaker       id party
# 0  2015-01-31  0.777486  Hilary Clinton    Q6294     D
# 1  2015-04-30  0.821875  Hilary Clinton    Q6294     D
# 2  2015-07-31  0.851274  Hilary Clinton    Q6294     D
# 3  2015-10-31  0.845122  Hilary Clinton    Q6294     D
# 4  2016-01-31  0.848509  Hilary Clinton    Q6294     D
# ..        ...       ...             ...      ...   ...
# 17 2019-04-30  0.157306     Marco Rubio  Q324546     R
# 18 2019-07-31  0.177612     Marco Rubio  Q324546     R
# 19 2019-10-31  0.160227     Marco Rubio  Q324546     R
# 20 2020-01-31  0.165417     Marco Rubio  Q324546     R
# 21 2020-04-30  0.178937     Marco Rubio  Q324546     R
#
# [572 rows x 5 columns]

# %%
#plotting
fig = px.line(df, x="date", y= 'prob_dem',hover_data=['speaker'],line_group = 'speaker',color='party',title='Influential politicians timeseries and our model prediction',labels = {'prob_dem' :'Political score'})
fig.add_hline(y = 0.5, line_dash = 'dash',annotation_text = 'neutral')
fig.show()
# Out:
# <div>                            <div id="e1c91bd3-6884-493d-a241-0baa6c5f10f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1c91bd3-6884-493d-a241-0baa6c5f10f0")) {                    Plotly.newPlot(                        "e1c91bd3-6884-493d-a241-0baa6c5f10f0",                        [{"customdata": [["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"], ["Hilary Clinton"]], "hovertemplate": "party=D<br>speaker=%{customdata[0]}<br>date=%{x}<br>Political score=%{y}<extra></extra>", "legendgroup": "D", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "D", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2015-01-31T00:00:00", "2015-04-30T00:00:00", "2015-07-31T00:00:00", "2015-10-31T00:00:00", "2016-01-31T00:00:00", "2016-04-30T00:00:00", "2016-07-31T00:00:00", "2016-10-31T00:00:00", "2017-01-31T00:00:00", "2017-04-30T00:00:00", "2017-07-31T00:00:00", "2017-10-31T00:00:00", "2018-01-31T00:00:00", "2018-04-30T00:00:00", "2018-07-31T00:00:00", "2018-10-31T00:00:00", "2019-01-31T00:00:00", "2019-04-30T00:00:00", "2019-07-31T00:00:00", "2019-10-31T00:00:00", "2020-01-31T00:00:00", "2020-04-30T00:00:00"], "xaxis": "x", "y": [0.7774861160846734, 0.8218747930507082, 0.8512741428152039, 0.8451220934301003, 0.8485090591325158, 0.8392814997909357, 0.8268870555895761, 0.8245769224317353, 0.8158922069273443, 0.8343779157037169, 0.8473892369117327, 0.8432972061224622, 0.8203552191029913, 0.8313869311695556, 0.828204053261744, 0.832110319768797, 0.8226325014361111, 0.8381791965056818, 0.8209416924154035, 0.8416063860120617, 0.8394269214953125, 0.822223264175283], "yaxis": "y"}, {"customdata": [["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"], ["Barack Obama"]], "hovertemplate": "party=D<br>speaker=%{customdata[0]}<br>date=%{x}<br>Political score=%{y}<extra></extra>", "legendgroup": "D", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "D", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2015-01-31T00:00:00", "2015-04-30T00:00:00", "2015-07-31T00:00:00", "2015-10-31T00:00:00", "2016-01-31T00:00:00", "2016-04-30T00:00:00", "2016-07-31T00:00:00", "2016-10-31T00:00:00", "2017-01-31T00:00:00", "2017-04-30T00:00:00", "2017-07-31T00:00:00", "2017-10-31T00:00:00", "2018-01-31T00:00:00", "2018-04-30T00:00:00", "2018-07-31T00:00:00", "2018-10-31T00:00:00", "2019-01-31T00:00:00", "2019-04-30T00:00:00", "2019-07-31T00:00:00", "2019-10-31T00:00:00", "2020-01-31T00:00:00", "2020-04-30T00:00:00"], "xaxis": "x", "y": [0.8691439906279917, 0.8555077551728295, 0.863285031267526, 0.8582857947299122, 0.876364291176781, 0.8506336190950573, 0.8704434704940879, 0.8628258032808623, 0.8492050728928806, 0.7843393300278042, 0.8243597804923406, 0.8377519668773321, 0.8292129814734814, 0.8091080425130317, 0.8344900311589019, 0.8581817711145131, 0.8422594599307693, 0.828947650915909, 0.8018917895140616, 0.8271711882531729, 0.8293427648376305, 0.8563708349413405], "yaxis": "y"}, {"customdata": [["Bernie Sanders"], ["Bernie Sanders"], ["Bernie Sanders"], ["Bernie Sanders"], [" ...

# %%
send_figure_to_internet(fig,'general_trend')
# Out:
# https://plotly.com/~ogim/19/
# link:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plotly.com/~ogim/19.embed" height="525" width="100%"></iframe>

# %%
#prepare data for better timeserie plotting 
def treat_df_timeseries_plot(df):
    # predict and add column
    df['proba_dem'] = predict(df.quotation_clean)
    # drop unecessary columns
    df = df[['date','proba_dem']]
    # Resample with a given frequency and add a numerical line (otherwise no linear regression =( )
    df = df.set_index('date')
    df = df.resample('1M').mean()
    df['monthsfrom'] = (df.index - df.index[0]).days/30
    df = df.reset_index()
    return df
    

dfls = []
#for every politician
for i in range(len(names)):
#do a single df resampled and ready for plotting+
    name = names[i]
    tempdf = data[data['id'] == ids[i]]
    if not tempdf.empty:
        tempdf = treat_df_timeseries_plot(tempdf)
        tempdf['speaker'] = name
        #append the df to the list
        dfls.append(tempdf)
        
#concat the single politicians resampled dfs: now it's ready for plotting
finaldf = pd.concat(dfls)

# %%
#finaldf['proba_dem'] = 1 - finaldf['proba_dem']
finaldf = finaldf.rename(columns={"monthsfrom": "months"})

# %%
#plotting 
fig = px.scatter(finaldf,x='months',y='proba_dem',color = 'speaker',title='Change of political score for the 20 most influential politician and with linear regressions', trendline="ols",labels = {'proba_dem' :'Political score','months' :'time'})
fig.update_xaxes(tickvals = finaldf.date,ticktext = finaldf.date,)
display(fig)

#optional presenting statistical results of the statsmodels linear regressions (equivalent to model.summary)
results = px.get_trendline_results(fig)
print(results)
# Out:
# <div>                            <div id="4f7aa7ac-19fa-4212-af37-d8cbc7452395" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f7aa7ac-19fa-4212-af37-d8cbc7452395")) {                    Plotly.newPlot(                        "4f7aa7ac-19fa-4212-af37-d8cbc7452395",                        [{"hovertemplate": "speaker=Donald Trump<br>time=%{x}<br>Political score=%{y}<extra></extra>", "legendgroup": "Donald Trump", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Donald Trump", "showlegend": true, "type": "scattergl", "x": [0.0, 0.9333333333333333, 1.9666666666666666, 2.966666666666667, 4.0, 5.0, 6.033333333333333, 7.066666666666666, 8.066666666666666, 9.1, 10.1, 11.133333333333333, 12.166666666666666, 13.133333333333333, 14.166666666666666, 15.166666666666666, 16.2, 17.2, 18.233333333333334, 19.266666666666666, 20.266666666666666, 21.3, 22.3, 23.333333333333332, 24.366666666666667, 25.3, 26.333333333333332, 27.333333333333332, 28.366666666666667, 29.366666666666667, 30.4, 31.433333333333334, 32.43333333333333, 33.46666666666667, 34.46666666666667, 35.5, 36.53333333333333, 37.46666666666667, 38.5, 39.5, 40.53333333333333, 41.53333333333333, 42.56666666666667, 43.6, 44.6, 45.63333333333333, 46.63333333333333, 47.666666666666664, 48.7, 49.63333333333333, 50.666666666666664, 51.666666666666664, 52.7, 53.7, 54.733333333333334, 55.766666666666666, 56.766666666666666, 57.8, 58.8, 59.833333333333336, 60.86666666666667, 61.833333333333336, 62.86666666666667, 63.86666666666667], "xaxis": "x", "y": [0.19314763231928206, 0.18576467269961092, 0.16961897738158208, 0.20647187134165262, 0.17279028524544904, 0.11927523712639405, 0.12839887463695077, 0.13410033042798872, 0.12831312054198749, 0.13761981572723525, 0.12576436864830595, 0.1335210248815336, 0.16582330855086255, 0.11972841573251514, 0.17483662001169584, 0.1362453567928891, 0.14336228235199047, 0.14524618671181894, 0.1515085129636617, 0.13917498880681392, 0.14927583398740749, 0.1843030985883086, 0.1403611705558988, 0.13983972156007718, 0.13981942612939835, 0.1219036207366954, 0.14683869399538407, 0.1263290924329187, 0.12946203805300172, 0.13375520036707395, 0.12027926560316841, 0.11751446270252157, 0.12670298005549405, 0.12911354326733424, 0.11601859372910948, 0.12373531174915395, 0.12600623422468937, 0.1269592196245633, 0.1202896649592804, 0.1087889902694859, 0.11054725494308659, 0.11109952626394594, 0.10554063840747625, 0.1160865673948966, 0.11549560166485165, 0.11907122044853727, 0.12379088390114622, 0.12061453281549082, 0.1286515742521418, 0.11515050945932782, 0.12105981148357546, 0.1294746737763121, 0.11981437689101525, 0.12020079248053393, 0.13101022461424405, 0.1178257977853603, 0.11911649005003874, 0.12227465631507642, 0.1360994227867892, 0.137142025218156, 0.12702100847775558, 0.13549898290344253, 0.1465978459489575, 0.14775541078238114], "yaxis": "y"}, {"hovertemplate": "<b>OLS trendline</b><br>proba_dem = -0.000592757 * months + 0.153529<br>R<sup>2</sup>=0.280060<br><br>speaker=Donald Trump<br>time=%{x}<br>Political score=%{y} <b>(trend)</b><extra></extra>", "legendgroup": "Donald Trump", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Donald Trump", "showlegend": false, "type": "scattergl", "x": [0.0, 0.9333333333333333, 1.9666666666666666, 2.966666666666667, 4.0, 5.0, 6.033333333333333, 7.066666666666666, 8.066666666666666, 9.1, 10.1, 11.133333333333333, 12.166666666666666, 13.133333333333333, 14.166666666666666, 15.166666666666666, 16.2, 17.2, 18.233333333333334, 19.266666666666666, 20.266666666666666, 21.3, 22.3, 23.333333333333332, 24.366666666666667, 25.3, 26.333333333333332, 27.333333333333332, 28.366666666666667, 29.366666666666667, 30.4, 31.433333333333334, 32.43333333333 ...
#                      speaker  \
# 0               Donald Trump
# 1      Arnold Schwarzenegger
# 2                 Mike Pence
# 3                   Ted Cruz
# 4                Sarah Palin
# 5             Mitch McConnel
# 6                Mitt Romney
# 7                Dick Cheney
# 8                   Jeb Bush
# 9             Chris Christie
# 10                 Rand Paul
# 11                Ben Carson
# 12           Henry Kissinger
# 13               Marco Rubio
# 14            Hilary Clinton
# 15              Barack Obama
# 16            Bernie Sanders
# 17              Bill Clinton
# 18                 Joe Biden
# 19             Kamala Harris
# 20              Nancy Pelosi
# 21                   Al Gore
# 22              Andrew Cuomo
# 23         Michael Bloomberg
# 24  Alexandria Ocasio-Cortez
# 25           Charles Schumer
#
#                                        px_fit_results
# 0   <statsmodels.regression.linear_model.Regressio...
# 1   <statsmodels.regression.linear_model.Regressio...
# 2   <statsmodels.regression.linear_model.Regressio...
# 3   <statsmodels.regression.linear_model.Regressio...
# 4   <statsmodels.regression.linear_model.Regressio...
# 5   <statsmodels.regression.linear_model.Regressio...
# 6   <statsmodels.regression.linear_model.Regressio...
# 7   <statsmodels.regression.linear_model.Regressio...
# 8   <statsmodels.regression.linear_model.Regressio...
# 9   <statsmodels.regression.linear_model.Regressio...
# 10  <statsmodels.regression.linear_model.Regressio...
# 11  <statsmodels.regression.linear_model.Regressio...
# 12  <statsmodels.regression.linear_model.Regressio...
# 13  <statsmodels.regression.linear_model.Regressio...
# 14  <statsmodels.regression.linear_model.Regressio...
# 15  <statsmodels.regression.linear_model.Regressio...
# 16  <statsmodels.regression.linear_model.Regressio...
# 17  <statsmodels.regression.linear_model.Regressio...
# 18  <statsmodels.regression.linear_model.Regressio...
# 19  <statsmodels.regression.linear_model.Regressio...
# 20  <statsmodels.regression.linear_model.Regressio...
# 21  <statsmodels.regression.linear_model.Regressio...
# 22  <statsmodels.regression.linear_model.Regressio...
# 23  <statsmodels.regression.linear_model.Regressio...
# 24  <statsmodels.regression.linear_model.Regressio...
# 25  <statsmodels.regression.linear_model.Regressio...

# %%
send_figure_to_internet(fig,'top20trend')
# Out:
# https://plotly.com/~ogim/14/
# link:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plotly.com/~ogim/14.embed" height="525" width="100%"></iframe>

# %% [markdown]
# What are the overall parties trends?

# %%
# create datatframes: Republicans vs Democrats
rep = data[data['party_label'] == 'R']
dem = data[data['party_label'] == 'D']
dfs = [rep,dem]

# %%
dfls = []
republican = True
#Same procedure as before to do a single df resampled and ready for plotting
for dataframe in dfs:
    dataframe = treat_df_timeseries_plot(dataframe)
    #relabel resampled data
    if republican:
        dataframe['party'] = 'R'
        republican = False
    else:
        dataframe['party'] = 'D'
    #append resampled dataframe
    dfls.append(dataframe)
    
#concat the two resampled dataframes
finaldf = pd.concat(dfls)
# Out:
# C:\Users\mauro\Anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Fixing params for the plot
finaldf = finaldf.rename(columns={"monthsfrom": "months"})
finaldf['proba_dem'] = 1 -finaldf['proba_dem']

# %%
#plotting 
color_code = ["red", "blue"] if finaldf.party.values[0] == 'R' else [ "blue","red"]
fig = px.scatter(finaldf,x='months',y='proba_dem',color = 'party',title='Overall political score trend over time: we observe that the parties avg scores are diverging  ', trendline="ols",labels = {'proba_dem' :'Political Score','months' :'time'},color_discrete_sequence=color_code)
fig.update_xaxes(tickvals = finaldf.date,ticktext = finaldf.date,)
display(fig)

#optional presenting statistical results of the statsmodels linear regressions (equivalent to model.summary)
# results = px.get_trendline_results(fig)
# print(results)
# Out:
# <div>                            <div id="22d60397-084b-4e37-99e5-954976b52a7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22d60397-084b-4e37-99e5-954976b52a7c")) {                    Plotly.newPlot(                        "22d60397-084b-4e37-99e5-954976b52a7c",                        [{"hovertemplate": "party=R<br>time=%{x}<br>Political Score=%{y}<extra></extra>", "legendgroup": "R", "marker": {"color": "red", "symbol": "circle"}, "mode": "markers", "name": "R", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.0, 0.9333333333333333, 1.9666666666666666, 2.966666666666667, 4.0, 5.0, 6.033333333333333, 7.066666666666666, 8.066666666666666, 9.1, 10.1, 11.133333333333333, 12.166666666666666, 13.133333333333333, 14.166666666666666, 15.166666666666666, 16.2, 17.2, 18.233333333333334, 19.266666666666666, 20.266666666666666, 21.3, 22.3, 23.333333333333332, 24.366666666666667, 25.3, 26.333333333333332, 27.333333333333332, 28.366666666666667, 29.366666666666667, 30.4, 31.433333333333334, 32.43333333333333, 33.46666666666667, 34.46666666666667, 35.5, 36.53333333333333, 37.46666666666667, 38.5, 39.5, 40.53333333333333, 41.53333333333333, 42.56666666666667, 43.6, 44.6, 45.63333333333333, 46.63333333333333, 47.666666666666664, 48.7, 49.63333333333333, 50.666666666666664, 51.666666666666664, 52.7, 53.7, 54.733333333333334, 55.766666666666666, 56.766666666666666, 57.8, 58.8, 59.833333333333336, 60.86666666666667, 61.833333333333336, 62.86666666666667, 63.86666666666667], "xaxis": "x", "y": [0.2678508615900552, 0.2685354573065707, 0.2714465223004481, 0.26763787431260044, 0.2596354392852994, 0.2652738174636595, 0.24379737422782866, 0.2360404714327673, 0.23287992182767459, 0.247990435667077, 0.2299006298147679, 0.2255432490458671, 0.24259437672871398, 0.2327272046133506, 0.23290002962242018, 0.24207631377326955, 0.24474527565574844, 0.23648457717536786, 0.2331006000285034, 0.2387214211283053, 0.2437162206236716, 0.23038826778119126, 0.20834802776558714, 0.2338614567182069, 0.19990324241207502, 0.20878284998747, 0.23333208183122656, 0.22335273360735886, 0.2314054836428674, 0.23245531511953332, 0.22373147916381853, 0.22400723271519996, 0.24200486824802192, 0.24236187306499346, 0.24510147564055051, 0.2384108047003135, 0.23080988258074908, 0.24262550200916566, 0.2446169430076821, 0.23322726330153976, 0.2257222732519727, 0.22118563457340412, 0.20713564881290292, 0.2207234262834299, 0.22125914956950998, 0.22947703857458068, 0.23135898690880852, 0.23056208218552332, 0.2271703964176166, 0.228514737183799, 0.23163541673275345, 0.232065584098736, 0.22126099998034654, 0.21711014727991218, 0.21382529422115393, 0.21298919820534845, 0.21850619718428688, 0.21377419742065185, 0.226298356120468, 0.22071141819637563, 0.21841333886062442, 0.22983561445030665, 0.23943035547525415, 0.23704768168970114], "yaxis": "y"}, {"hovertemplate": "<b>OLS trendline</b><br>proba_dem = -0.000464627 * months + 0.247773<br>R<sup>2</sup>=0.337643<br><br>party=R<br>time=%{x}<br>Political Score=%{y} <b>(trend)</b><extra></extra>", "legendgroup": "R", "marker": {"color": "red", "symbol": "circle"}, "mode": "lines", "name": "R", "showlegend": false, "type": "scatter", "x": [0.0, 0.9333333333333333, 1.9666666666666666, 2.966666666666667, 4.0, 5.0, 6.033333333333333, 7.066666666666666, 8.066666666666666, 9.1, 10.1, 11.133333333333333, 12.166666666666666, 13.133333333333333, 14.166666666666666, 15.166666666666666, 16.2, 17.2, 18.233333333333334, 19.266666666666666, 20.266666666666666, 21.3, 22.3, 23.333333333333332, 24.366666666666667, 25.3, 26.333333333333332, 27.333333333333332, 28.366666666666667, 29.366666666666667, 30.4, 31.433333333333334, 32.43333333333333, 33.46666666666667, 34.46666666666667, 35.5, 36.53333333333333, 37.466 ...

# %%
send_figure_to_internet(fig,'overallparties')
# Out:
# https://plotly.com/~ogim/16/
# link:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plotly.com/~ogim/16.embed" height="525" width="100%"></iframe>

# %% [markdown]
# As we have seen previously, our simple model is able to grasp the political inclination starting from the quotations. It is therefore evident to us that a company with important resources can easily develop a more sophisticated model, which is able, starting from the information (eg posts) we publish on social networks, to trace our political orientation. Therefore a political party can easily target the right people with advertisements so that they can influence the results of political elections as much as possible. Or worse still, a foreign body could influence another country's political elections. These machine learing models could make these phenomena economically feasible.

# %% [markdown]
# The final part of our analyses is in the this [notebook](part3_5-topic_and_model_evaluation.ipynb)
