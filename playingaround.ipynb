# %%
import bz2
import json

import pandas as pd

import texthero as hero

import texthero.preprocessing as hp

from helpers import *
from prepro_party_labeling import *

# %%
QUOTES_2020_PATH,SPEAKER_ATTRIBUTES_PATH
# Out:
# ('data.nosync/quotebank/quotes-2020.json.bz2',
#  'data.nosync/wikidata/speaker_attributes.parquet/')

# %%
df_sa = load_wikidata()
df_sa_labeled = speaker_attribute_processing(df_sa)

# %%
df_sa[df_sa['id'] == 'Q7323929']
# Out:
#         aliases            date_of_birth nationality      gender   lastrevid  \
# 2460767    None  [+1950-00-00T00:00:00Z]       [Q30]  [Q6581097]  1359035669
#
#         ethnic_group US_congress_bio_ID           occupation party  \
# 2460767         None               None  [Q188094, Q1622272]  None
#
#         academic_degree        id            label candidacy  type religion
# 2460767            None  Q7323929  Richard Baldwin      None  item     None

# %%
raw_data_filepath = QUOTES_2020_PATH
with pd.read_json(raw_data_filepath, lines=True, compression='bz2', chunksize=100000) as df_reader:
    for df_quotes_chunk in df_reader:

        df = df_quotes_chunk.drop(['phase', 'urls', 'probas'], axis=1)

        display(df[df['speaker'].str.lower() == ('richard baldwin')])
# Out:
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                   quoteID                                          quotation  \
# 457864  2020-03-09-043349  Or it might be that we finally understand that...
#
#                 speaker                   qids                date  \
# 457864  Richard Baldwin  [Q57038414, Q7323929] 2020-03-09 15:29:55
#
#         numOccurrences
# 457864               3
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                    quoteID                                          quotation  \
# 1081793  2020-03-13-038038  It's not exponential: an economist's view of t...
#
#                  speaker                   qids                date  \
# 1081793  Richard Baldwin  [Q57038414, Q7323929] 2020-03-13 23:26:20
#
#          numOccurrences
# 1081793               1
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                    quoteID                                          quotation  \
# 1794484  2020-03-09-064285  This one is economically big, because it is no...
#
#                  speaker                   qids                date  \
# 1794484  Richard Baldwin  [Q57038414, Q7323929] 2020-03-09 15:29:55
#
#          numOccurrences
# 1794484               3
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                    quoteID                                          quotation  \
# 2252070  2020-04-03-027828  If you lose a few hundred jobs in London, no o...
#
#                  speaker                   qids                date  \
# 2252070  Richard Baldwin  [Q57038414, Q7323929] 2020-04-03 01:05:09
#
#          numOccurrences
# 2252070               4
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                    quoteID                                          quotation  \
# 2599660  2020-02-26-002266  acquire lots and lots of skills in something t...
#
#                  speaker                   qids                date  \
# 2599660  Richard Baldwin  [Q57038414, Q7323929] 2020-02-26 23:11:50
#
#          numOccurrences
# 2599660               2
#                    quoteID                                          quotation  \
# 2602000  2020-01-23-114510  What I'm worried about is that job displacemen...
#
#                  speaker                   qids                date  \
# 2602000  Richard Baldwin  [Q57038414, Q7323929] 2020-01-23 18:28:43
#
#          numOccurrences
# 2602000               2
#                    quoteID                                          quotation  \
# 2773706  2020-04-03-008023  But if you lose a few hundred of these good jo...
#
#                  speaker                   qids                date  \
# 2773706  Richard Baldwin  [Q57038414, Q7323929] 2020-04-03 01:05:09
#
#          numOccurrences
# 2773706               4
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                    quoteID                                          quotation  \
# 4471768  2020-01-23-114867  What we have is displacement being driven at t...
#
#                  speaker                   qids                date  \
# 4471768  Richard Baldwin  [Q57038414, Q7323929] 2020-01-23 18:28:43
#
#          numOccurrences
# 4471768               2
#                    quoteID                                          quotation  \
# 4598005  2020-03-09-030076  In the longer run, it could encourage more pop...
#
#                  speaker                   qids                date  \
# 4598005  Richard Baldwin  [Q57038414, Q7323929] 2020-03-09 15:29:55
#
#          numOccurrences
# 4598005               3
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
#                    quoteID                                          quotation  \
# 4742184  2020-03-09-057809  The size of the economic shock is a different ...
#
#                  speaker                   qids                date  \
# 4742184  Richard Baldwin  [Q57038414, Q7323929] 2020-03-09 15:29:55
#
#          numOccurrences
# 4742184               3
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, qids, date, numOccurrences]
# Index: []
